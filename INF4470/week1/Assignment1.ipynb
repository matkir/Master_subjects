# %% [markdown]
# # Mathias Kirkerød / mathiaki
# ## uke 1

# %% [markdown]
# # Oppgave 1 Trigonometriske funksjoner
#
# ## a)

# %%
from numpy import *
import matplotlib.pyplot as plt

t=linspace(-1,2.5,5000)

plt.subplot(2,2,1)
func1=cos(2*pi*t)
plt.plot(t,func1,'r')

plt.subplot(2,2,2)
func2=cos(2*pi*t+pi)
plt.plot(t,func2,'g')

plt.subplot(2,2,3)
func3=cos(8*pi*t)
plt.plot(t,func3,'b')

plt.subplot(2,2,4)
func4=cos(4*pi*t- pi/3)
plt.plot(t,func4,'y')


plt.show()

# %% [markdown]
# ## b)
# ##### 1)
#
# *frekvens*  : 2
#
# *Ampliude*  : 2
#
# *faseskift* : 0
#
# ##### 2)
#
# *frekvens*  : 4
#
# *Ampliude*  : 1
#
# *faseskift* : $ \pi $
#
#
# ##### 3)
#
# *frekvens*  : 1
#
# *Ampliude*  : 1
#
# *faseskift* : $ \frac{- \pi}{  2}$
#
#
# ##### 4)
#
# *frekvens*  : 0.5
#
# *Ampliude*  : 1
#
# *faseskift* : litt over 1

# %% [markdown]
# ## c)
#
# Bruk fasoraddisjon og vis at følgende funksjoner kan skrives på formen $ Acos(ωt +φ): $
#
# #### 1)
# $$ \cos{(\omega t)} + \cos{(\omega t + \phi)} \\ $$
#
# $$ \frac{1}{2} (e^{j\omega} + e^{−j\omega})+\frac{1}{2} (e^{j\omega+\phi} + e^{−j\omega-\phi})\\ $$
#
# $$ \frac{1}{2} e^{j\omega} + e^{j\omega+\phi}  e^{−j\omega}  e^{−j\omega-\phi} $$
#
# $$ \frac{1}{2} e^{j\omega} + e^{j\omega+\phi}  e^{−j\omega}  e^{−j\omega-\phi} $$
#
# #### 2)
#  4 cos(ωt +π/2) +1.5 cos(ωt −π/3)
# #### 3)
#  cos(ωt +4π/3) +cos(ωt −5π/3)

# %% [markdown]
# ## Oppgave 2 Diskrete trigonometriske funksjoner
# ### a)
# *Hvilke av de følgende diskrete funksjonene er periodiske, og hva er periodene deres (dvs. N)?*
# 1. cos(0.5n+π/2)
# Er ikke periodisk.
# 2. cos(πn+π/2)
# Er periodisk. Perioden er N=2
# 3. $\cos{(\frac{\sqrt{2}}{2}\pi n )} $
# Er ikke periodisk, grunnet at  $\sqrt{2}$ er et irrasjonelt tall, og vi kan dermed ikke finne f.
#
# ### b)
# *Angi den cosinus-funksjonen i diskret tid som vi får ved å ta 5 sampler per halve periode av en cosinus i kontinuerlig tid.*
#
# $ \cos{(10\pi t)}$
#
# ### c)
# *Angi den cosinus-funksjonen i diskret tid som vi får ved å ta sampler med avstand 1 sekunder av en cosinus i kontinuerlig tid med vinkelfrekvens 1.*
#
# $ \cos{(\pi t)}$

# %% [markdown]
# ## Oppgave 3 Regning med komplekse tall
#
# ### a)
# *Gjør følgende utregninger. Om svaret står oppgitt må mellomregning inkluderes.*
# #### 1.
# $|3+ j4| = $
# $$|3+ j4| = $$
#
# $$\sqrt{3^2+4^2} = 5$$
#
#
# #### 2.
# *$ \frac{1}{3+j4}$ til kartesisk form = *
#
# Vi ganger først med den komplekskonjugerte:
# $$ \frac{1 (3-4j)}{(3+j4) (3-4j)}$$
#
# $$ \frac{3-4j}{9-12j+12j-16j^2}$$
#
# Siden $j^2=-1$
# $$ \frac{3}{25}+\frac{4j}{25}$$
#
#
# #### 3.
# *$\frac{1+j2}{1+e^{jπ/2}}$ til kartesisk form = *
#
# $e^{jπ/2}=j$, så vi kan skrive om til:
#
# $$\frac{1+j2}{1+j}$$
#
# $$\frac{(1+j2)(1-j)}{(1+j)(1-j)}$$
#
# $$\frac{3+j}{2}$$
#
# $$\frac{3}{2}+\frac{j}{2}$$
#
#
#
# #### 4.
# *$(−1)^n +e^{jπn}$ = , hvor n er et heltall *
#
# 1st:
# $(-1)^n$ vil periodisk bytte mellom -1 for oddetall og 1 for partall.
#
# 2nd:
# $e^{jπn}$ vil periodisk bytte mellom -1 for oddetall og 1 for partall. Siden $e^{jπ}$ har en periode på 2.
#
# legger vi dette sammen så får vi:
# $2 ·(−1)^n$
#
# ### b)
# *Vis at $(cos(θ) + jsin(θ))^n = (cos(θn) + jsin(θn))$ *
#
#
# Vi definerer $e^{j\theta} = (cos(\theta)+j sin(\theta))$
#
# Dermed kan vi ta
# $$ e^{(j\theta)^{n}}  =>  (cos(\theta)+j sin(\theta))^n $$
#
# Vi kan nå bruke potensoperasjoner for å gjøre:
#
# $ e^{(j\theta n)}$ som samsvarer tilsier at:
#
# $$ e^{(j\theta n)} = (cos(\theta n)+j sin(\theta n)) $$
#
# altså:
#
# $$ (cos(\theta )+j sin(\theta ))^n= (cos(\theta n)+j sin(\theta n)) $$

# %% [markdown]
# ## Oppgave 4 Komplekse tall og det komplekse tallplanet

# %%
from math import atan2,sqrt
# z = a + jb
a=0
b=1
r=sqrt(a**2+b**2)
theta=atan2(b,a)

kart=complex(a,b)
polar=(r,theta)

print('kartesisk = {0}'.format(kart))
print('polar = {0}'.format(polar))
# Out:
# kartesisk = 1j
# polar = (1.0, 1.5707963267948966)

# %% [markdown]
# Eller vist med figur:
# ![figur](img1.gif)
# Her er polare koordinater regnet ut i radianer gitt a og b.

# %% [markdown]
# ### b)
# Ved å gange med den komplekskonjugerte vil vi fjerne alle imaginære ledd fra likningen:
#
# Dette er fordi $j^2=-1$

# %%
from numpy import *
import matplotlib.pyplot as plt

a=2
b=1

num1=complex(a,b)
num2=complex(a,-b)
num3=num1*num2
print(num1,'*',num2,'=',num3)

plt.plot([real(num1)],[imag(num1)],'bo')
plt.plot([real(num2)],[imag(num2)],'ro')
plt.plot([real(num3)],[imag(num3)],'go')
plt.xlim(0,6)

plt.show()
# Out:
# (2+1j) * (2-1j) = (5+0j)

# %% [markdown]
# ![euelers](img2.png)
# Her ser vi at $\theta$ (eller *x* i figur) er vinkel som spenner seg ut i det imaginære planet
# og ettersom $\theta$ øker, vil vi bevege oss rundt planet, helt til $\theta=2\pi$, hvor vi har gått en hel runde.
#
# Å opphøye med k, er det samme som å gange $\theta$ med k

# %%
from numpy import *
import matplotlib.pyplot as plt

k=array([1,2,3,4,5])
theta=pi/4
tmp1=cos(theta*k)
tmp2=sin(theta*k)


plt.plot(tmp1,tmp2,'ro')

t=linspace(0,2*pi,10000)
plt.plot(cos(t),sin(t))

plt.axis('equal')
plt.show()

# %% [markdown]
# Velger vi $\theta = 2\pi$ vil vi ha $e^{j\theta k}=1$ uavhengig av k

# %% [markdown]
# ## Oppgave 5 Regning med komplekse tall
# ### a)
# *Regn ut følgende for polar $(z = re^{jθ})$ og/eller kartesisk (z = a+ jb) form som angitt.*
#
# * **  $z^∗$ på polar form**
#
# Polar:
# $$ re^{-j\theta} $$
#
# &nbsp;
#
# * **  $ zz^∗ $ på polar og kartesisk form (hva er dette det samme som?)**
#
#
# Kartesisk:  $$ (a+jb)(a-jb) $$
#             $$ a^2+b^2 $$
#
# Polar:   $$ r^2 e^{0}  = r^2 $$
#
# Samme som:  $$ |z|^2 $$
#
# &nbsp;
#
# * ** $ z^k $ på polar form**
#
# Polar:
#     $$ (a+ib)^k $$
#     $$ e^{{j\theta} ^k} $$
#     $$ e^{j\theta k} $$
#     $$ cos(k \theta) + j sin(k \theta) $$
#
# &nbsp;
#
# * **$ z+z^∗ $ på polar og kartesisk form [2r cosφ]**
#     $$ z+z^∗ =$$
#
# Polar:
#     $$ re^{j\theta}+re^{-j\theta} $$
#     $$ r(cos(\theta)+j sin(\theta))+r(cos(\theta)-j sin(\theta)) $$
#     $$ 2rcos(\theta) $$
#
# Kartesisk:
#     $$ (a+jb)+(a-jb) $$
#     $$ 2a $$
#
#
# &nbsp;
#
# * **$z−z^∗$ på polar og kartesisk form**
#     $$z−z^∗=$$
# Polar:
#     $$ re^{j\theta}-re^{-j\theta} $$
#     $$ r(cos(\theta)+j sin(\theta))-r(cos(\theta)-j sin(\theta)) $$
#     $$ 2rjsin(\theta) $$
#
# Kartesisk:
#     $$ (a+jb)-(a-jb) $$
#     $$ 2jb $$
#
#
# &nbsp;
#
# * **$\frac{1}{2}(z+z^∗)$ på polar og kartesisk form**
#     $$\frac{1}{2}(z+z^∗)=$$
# Polar: (samme som over /2)
#     $$a$$
# Kartesisk:
#     $$rcos(\theta)$$
#
# &nbsp;
#
# * ** $\frac{1}{2j}(z-z^∗)$ på polar og kartesisk form**
#    $$\frac{1}{2j}(z+z^∗)=$$
#
# Polar: (samme som over /2)
#     $$b$$
# Kartesisk:
#     $$jsin(\theta)$$
#
#
# &nbsp;
#
# * ** $z^{−1}$ på polar og kartesisk form**
#     $$z^{−1}=$$
# Kartesisk: (ganger med den kompleksjonjugerte av nevner)
#     $$\frac{(1)(a-jb)}{(a+jb)(a-jb)}$$
#     $$\frac{(a-jb)}{a^2+b^2}$$
# Polar: (ganger med den kompleksjonjugerte av nevner)
#     $$\frac{1}{re^{j\theta}}$$
#     $$\frac{1*re^{-j\theta}}{re^{j\theta}*re^{-j\theta}}$$
#     $$\frac{e^{-j\theta}}{r}$$
#
#
# &nbsp;
#
# * **Bruk punktene over for å finne et uttrykk for cos(θ) og sin(θ) ved komplekse eksponentialer (Euler identitetene).**
# $$e^{j\theta}=cos(\theta)+jsin(\theta)$$
#
# $$cos(\theta)=\frac{1}{2}(e^{j\theta}+e^{-j\theta})$$
#
# $$sin(\theta)=\frac{1}{2j}(e^{j\theta}-e^{-j\theta})$$
#
#
# &nbsp;
#
# * ** Hva er mengden av alle punkter som kan beskrives med det komplekse eksponentialet $z = e^{jθ}$ ,0 ≤ θ < 2π?**
#
# Vi ser etter en z=a+jb, hvor $\sqrt{a^2+b^2}=1$
#
# Hvis vi gjør dette il vi treffe alle punktene på enhetssirkelenen med radius 1. Sammen som $z = e^{jθ}$.
#
# Så mengden er alle tall i C som oppfyller $\sqrt{a^2+b^2}=1$
#
#
# &nbsp;
#
# * ** Hva er forskjellen på $z^{−1} og z^∗$? Beskriv $z^{−1}$ utifra $|z|^2 $og$ z^∗$.**
#
# z^1 er normalisert.
#
# $$ \frac{1}{r^2}z^*$$
#
# $$ \frac{1}{r^2}re^{-j\theta}$$
#
# ganger vi dette med z får vi:
#
# $$ \frac{1}{r^2}re^{-j\theta} re^{j\theta} = 1$$
#
# Altså $zz^{-1}=1$
#
# ### b)
# Skriv følgende tall som komplekse tall på polar form (k er et vilkårlig heltall).
#
# 1. $e^{j(2\pi k+ \pi)} = −1$
#
# 2. $e^{j\pi k} = (−1)^k$
#
# 3. $e^{j\frac{\pi}{2}k} = j^k$

# %% [markdown]
# ## Oppgave 6 Geometriske rekker
# ### a)
# Beregn verdien til følgende endelige geometriske rekker:
# 1. $ \sum\limits_{k=0}^{100} 23^k =$
#
#    $$\frac{1-\alpha^M}{1-\alpha} = $$
#
#    $$\frac{1-23^{101}}{1-23} = 1.5*10^{136}$$
#
#
# 2. $ \sum\limits_{k=5}^{19} 4.5^k =$
#
#    $$\frac{1-\alpha^M}{1-\alpha} = $$
#
#    $$(\frac{1-4.5^{20}}{1-4.5})- (\frac{1-4.5^{5}}{1-4.5})  = 3.3 *10^{12}$$
#
# ### b)
# Bestem hvilke av de følgende uendelige geometriske rekkene som konvergerer, og beregn verdien til disse:
#
#
# *Rekker som konvergerer har $|\alpha| < 1$, så rekke nummer 2 og 4 vil konvergere.*
# 1. $ \sum\limits_{k=0}^{\infty} {(\frac{3}{a})}^k = $ ,$  a > 4$
#    $$\frac{1}{1-\alpha} = $$
#
#    $$\frac{1}{1-\frac{3}{a}} = \frac{a}{a-3} $$
#
#
#
# 3. $ \sum\limits_{k=-\infty}^{\infty} {2}^{-|k|} = $
#
#     $$\frac{1}{1-\frac{1}{2}}+\frac{1}{1-\frac{1}{2}}-1 =3  $$
#
#
#
# ### c)
# Finn konvergensområdet til følgende uendelige geometriske rekker. Om svaret er oppgitt, vis mellomregning.
# 1. $ \sum\limits_{k=0}^{\infty} \frac{x}{2}^{k} , x ∈ R $
#
#    $$ \sum\limits_{k=0}^{\infty} \frac{x}{2}^{k} $$
#
#    $$-2<x<2$$
#
# 2. $ \sum\limits_{k=0}^{\infty} ({x}^{-1})^{k} $ , x ∈ R
#
#    $$ \sum\limits_{k=0}^{\infty} ({x}^{-1})^{k} $$
#
#    $$ |\alpha| = \frac{1}{|x|} $$
#
#    $$ x>1 \ \lor \!\, \ x<-1$$
#
# 3. $ \sum\limits_{k=0}^{\infty} ({z}^{-1})^{k} $ ,z ∈ C [1√a 2 +b 2 < 1]
#
#     $$ \sum\limits_{k=0}^{\infty} ({z}^{-1})^{k} $$
#
#     $$ \frac{z^*}{|z|^2} < 1$$
#
#     $$ \frac{re^{-j\theta}}{r^2} < 1$$
#
#     $$ \frac{e^{-j\theta}}{r} < 1$$
#
# Teller vil aldri ha annen lengde enn 1
#
# Nevner må da ha lengde
# $$ \frac{1}{\sqrt{a^2+b^2}}$$
#
#
#
# 4. $ \sum\limits_{k=0}^{\infty} ({x}^{2})^{k} $, x ∈ R
#
#    $$ \sum\limits_{k=0}^{\infty} ({x}^{2})^{k} $$
#
#    $$ \sqrt{|x^2|}<1$$
#
#    $$|x|<1$$
#
# 5. $ \sum\limits_{k=0}^{\infty} {2}^{k}z^{k} $  ,z ∈ C
#
#     $$ \sum\limits_{k=0}^{\infty} {2}^{k}z^{k}  $$
#
#     $$\frac{2^k}{z^k}$$
#
#     $$ |\alpha| = \frac{2}{z} $$
#
#     $$|\frac{2}{z}| < 1$$
#
#     $$ 2 < |z| $$
