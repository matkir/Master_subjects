# %% [markdown]
# # Oppgave 1 Trigonometriske funksjoner
#
# ## a)

# %%
from numpy import *
import matplotlib.pyplot as plt

t=linspace(-1,2.5,5000)

plt.subplot(2,2,1)
func=cos(2*pi*t)
plt.plot(t,func)

plt.subplot(2,2,2)
func=cos(2*pi*t+pi)
plt.plot(t,func)

plt.subplot(2,2,3)
func=cos(8*pi*t)
plt.plot(t,func)

plt.subplot(2,2,4)
func=cos(4*pi*t- pi/3)
plt.plot(t,func)


plt.show()

# %% [markdown]
# ## b)
# ##### 1)
#
# *frekvens*  : 2
#
# *Ampliude*  : 2
#
# *faseskift* : 0
#
# ##### 2)
#
# *frekvens*  : 4
#
# *Ampliude*  : 1
#
# *faseskift* : $ \pi $
#
#
# ##### 3)
#
# *frekvens*  : 1
#
# *Ampliude*  : 1
#
# *faseskift* : $ \frac{- \pi}{  2}$
#
#
# ##### 4)
#
# *frekvens*  : 0.5
#
# *Ampliude*  : 1
#
# *faseskift* : litt over 1

# %% [markdown]
# ## c)
#
# Bruk fasoraddisjon og vis at følgende funksjoner kan skrives på formen $ Acos(ωt +φ): $
#
# #### 1)
# $$ \cos{(\omega t)} + \cos{(\omega t + \phi)} \\ $$
#
# $$ \frac{1}{2} (e^{j\omega} + e^{−j\omega})+\frac{1}{2} (e^{j\omega+\phi} + e^{−j\omega-\phi})\\ $$
#
# $$ \frac{1}{2} e^{j\omega} + e^{j\omega+\phi}  e^{−j\omega}  e^{−j\omega-\phi} $$
#
# $$ \frac{1}{2} e^{j\omega} + e^{j\omega+\phi}  e^{−j\omega}  e^{−j\omega-\phi} $$
#
# #### 2)
#  4 cos(ωt +π/2) +1.5 cos(ωt −π/3)
# #### 3)
#  cos(ωt +4π/3) +cos(ωt −5π/3)

# %% [markdown]
# ## Oppgave 2 Diskrete trigonometriske funksjoner
# ### a)
# Hvilke av de følgende diskrete funksjonene er periodiske, og hva er periodene deres (dvs. N)?
# 1. cos(0.5n+π/2)
# 2. cos(πn+π/2)
# 3. $\cos{(\frac{\sqrt{2}}{2}\pi n )} $
#
# ### b)
#  Angi den cosinus-funksjonen i diskret tid som vi får ved å ta 5 sampler per halve periode av en cosinus i kontinuerlig tid.
# ### c)
# Angi den cosinus-funksjonen i diskret tid som vi får ved å ta sampler med avstand 1 sekunder av en cosinus i kontinuerlig tid med vinkelfrekvens 1.

# %% [markdown]
# ## Oppgave 3 Regning med komplekse tall
#
# ### a)
# Gjør følgende utregninger. Om svaret står oppgitt må mellomregning inkluderes.
# #### 1.
# |3+ j4| = ?
#
# #### 2.
# 1 /3+j4
# til kartesisk form =
#
#
# #### 3.
# 1+j2
# 1+e
# jπ/2
# til kartesisk form = ?
#
# #### 4.
# (−1)^n +ejπn = ?, hvor n er et heltall 2 ·(−1)n
#
# ### b)
# Vis at
# (cos(θ) + jsin(θ))n = (cos(θn) + jsin(θn))

# %% [markdown]
# ## Oppgave 4 Komplekse tall og det komplekse tallplanet

# %% [markdown]
# ## Oppgave 5 Regning med komplekse tall
# ### a)
# Regn ut følgende for polar $(z = re^{jθ})$ og/eller kartesisk (z = a+ jb) form som angitt.
#
# 1. z∗ på polar form
# 2. zz∗ på polar og kartesisk form (hva er dette det samme som?)
# 3. z^k på polar form
# 4. z+z∗ på polar og kartesisk form [2r cosφ]
# 5. z−z∗ på polar og kartesisk form
# 6. 1/2(z+z∗) på polar og kartesisk form
# 7. 1/2 j(z−z∗) på polar og kartesisk form
# 8. z−1 på polar og kartesisk form
# 9. Bruk punktene over for å finne et uttrykk for cos(θ) og sin(θ) ved komplekse eksponentialer (Euler identitetene).
# 10. Hva er mengden av alle punkter som kan beskrives med det komplekse eksponentialet z = ejθ ,0 ≤ θ < 2π?
# 11. Hva er forskjellen på z−1 og z∗? Beskriv z−1 utifra |z|2 og z∗.
#
# ### b)
# Skriv følgende tall som komplekse tall på polar form (k er et vilkårlig heltall). Som eksempel kan tallet 1 skrives som 1ej·2πk.
#
# 1. −1
# 2. (−1)k
# 3. jk

# %% [markdown]
# ## Oppgave 6 Geometriske rekker
# ### a)
# Beregn verdien til følgende endelige geometriske rekker:
# 1. ∑100 k=0 23k = ?
# 2. ∑ 19 k=5 (4.5) k = ? ( Tips: del opp summen for å endre summasjonsgrensene).
# ### b)
# Bestem hvilke av de følgende uendelige geometriske rekkene som konvergerer, og beregn verdien til disse:
# 1. ∑∞k=0 1k
# 2. ∑∞k=0 3 a k  ,a > 4
# 3. ∑∞k=−∞2−k
# 4. ∑∞k=−∞ 2−|k|
# ### c)
# Finn konvergensområdet til følgende uendelige geometriske rekker. Om svaret er oppgitt, vis mellomregning.
# 1. ∑∞k=0 x2^k   , x ∈ R
# 2. ∑∞k=0(x−1)^k , x ∈ R
# 3. ∑∞k=0(z−1)^k ,z ∈ C [1√a 2 +b 2 < 1]
# 4. ∑∞k=0(x2)^k , x ∈ R
# 5. ∑∞k=02kz^{−k}  ,z ∈ C |z| > 2
